# %%
import pandas as pd

# %%
tendulkar = pd.read_csv('tendulkar_ODI.csv')

# %%
tendulkar
# Out:
#      Unnamed: 0 Runs Mins   BF  4s 6s      SR Pos Dismissal Inns  \
# 0             1    0    -    2   0  0       0   5    caught    2
# 1             2    0    2    2   0  0       0   5    caught    2
# 2             3   36   51   39   5  0    92.3   6    caught    1
# 3             4   19   38   35   1  1   54.28   4    bowled    2
# 4             5   31   31   26   3  0  119.23   6    bowled    2
# ..          ...  ...  ...  ...  .. ..     ...  ..       ...  ...
# 290         291   18   21   14   2  0  128.57   2    caught    2
# 291         292    2    9    6   0  0   33.33   2    caught    2
# 292         293    3   21   12   0  0      25   2    caught    2
# 293         294   14   34   15   2  0   93.33   2   run out    2
# 294         295  114  205  147  12  1   77.55   2    caught    1
#
#         Opposition      Ground Start Date
# 0       v Pakistan  Gujranwala  18-Dec-89
# 1    v New Zealand     Dunedin   1-Mar-90
# 2    v New Zealand  Wellington   6-Mar-90
# ...

# %%
tendulkar.Runs.value_counts()
# Out:
# 1      16
# 2      14
# 0      12
# 4       9
# 21      8
#        ..
# 72      1
# 81      1
# 70*     1
# 82      1
# 138     1
# Name: Runs, Length: 118, dtype: int64

# %%
tendulkar['NotOut'] = tendulkar.Runs.apply(lambda x: x[-1] == '*')
tendulkar.Runs = tendulkar.Runs.apply(lambda x: x[:-1] if x[-1] == '*' else x)

# %%
tendulkar[tendulkar.NotOut]
# Out:
#      Unnamed: 0 Runs Mins   BF  4s 6s      SR Pos       Dismissal Inns  \
# 30           31   82  116   81   6  1  101.23   5         not out    1
# 37           38    8    8    6   0  0  133.33   5         not out    2
# 42           43   26    -   30   4  0   86.66   5         not out    2
# 46           47   28    -   43   2  0   65.11   5         not out    1
# 48           49   11   25   18   0  0   61.11   5         not out    2
# 73           74  127  175  138  15  1   92.02   2         not out    2
# 96           97   65  111   70   7  0   92.85   1         not out    2
# 110         111   82  110   86   6  0   95.34   4         not out    2
# 120         121  100  156  103  13  0   97.08   2         not out    2
# 124         125  127  155  130  13  1   97.69   2         not out    2
# 134         135  186  221  150  20  3     124   2         not out    1
# 159         160   70  129   70  13  0     100   2         not out    2
# ...

# %%
tendulkar.Runs.value_counts()
# Out:
# 1      16
# 2      14
# 0      12
# 4       9
# 21      8
#        ..
# 71      1
# 128     1
# 52      1
# 50      1
# 138     1
# Name: Runs, Length: 107, dtype: int64

# %%
tendulkar[tendulkar.Runs.apply(lambda x: 'DNB' in x)]
# Out:
#      Unnamed: 0  Runs Mins BF 4s 6s SR Pos Dismissal Inns    Opposition  \
# 8             9   DNB    -  -  -  -  -   -         -    2  v Bangladesh
# 38           39   DNB    -  -  -  -  -   -         -    2    v Zimbabwe
# 233         234  TDNB    -  -  -  -  -   -         -    -   v Sri Lanka
#
#          Ground Start Date  NotOut
# 8    Chandigarh  25-Dec-90   False
# 38         Pune  25-Mar-93   False
# 233     Kolkata   8-Feb-07   False

# %%
whenTendulkarBat = tendulkar[~tendulkar.Runs.apply(lambda x: 'DNB' in x)]

# %%
import matplotlib as plt
import seaborn as sns

# %%
whenTendulkarBat.Runs.value_counts().plot.barh()

# %%
tendulkar
# Out:
#      Unnamed: 0 Runs Mins   BF  4s 6s      SR Pos Dismissal Inns  \
# 0             1    0    -    2   0  0       0   5    caught    2
# 1             2    0    2    2   0  0       0   5    caught    2
# 2             3   36   51   39   5  0    92.3   6    caught    1
# 3             4   19   38   35   1  1   54.28   4    bowled    2
# 4             5   31   31   26   3  0  119.23   6    bowled    2
# ..          ...  ...  ...  ...  .. ..     ...  ..       ...  ...
# 290         291   18   21   14   2  0  128.57   2    caught    2
# 291         292    2    9    6   0  0   33.33   2    caught    2
# 292         293    3   21   12   0  0      25   2    caught    2
# 293         294   14   34   15   2  0   93.33   2   run out    2
# 294         295  114  205  147  12  1   77.55   2    caught    1
#
#         Opposition      Ground Start Date  NotOut
# 0       v Pakistan  Gujranwala  18-Dec-89   False
# 1    v New Zealand     Dunedin   1-Mar-90   False
# ...

# %%
whenTendulkarBat['4s'].value_counts().plot.barh()
